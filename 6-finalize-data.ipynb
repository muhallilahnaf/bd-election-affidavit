# %%
import pandas as pd

# %%
dfcan = pd.read_csv('data/candidates.csv')
dfcan.head()
# Out:
#    zillaID  constituencyID                        name  \
# 0        4             125           মোঃ সাব্বির আহমেদ
# 1        4             125  মুহাম্মদ মুস্তাফিজুর রহমান
# 2        4             125            মাহমুদা আলম মিতু
# 3        4             125          এম, মঈন আলম ফিরোজী
# 4        4             125          রফিকুল ইসলাম জামাল
#
#                                                  img  \
# 0  https://onss.ecs.gov.bd/document-service/api/v...
# 1  https://onss.ecs.gov.bd/document-service/api/v...
# 2  https://onss.ecs.gov.bd/document-service/api/v...
# 3  https://onss.ecs.gov.bd/document-service/api/v...
# 4  https://onss.ecs.gov.bd/document-service/api/v...
#
#                                 party  \
# 0                           স্বতন্ত্র
# 1               বাংলাদেশ লেবার পার্টি
# 2          জাতীয় নাগরিক পার্টি-এনসিপি
# 3                           স্বতন্ত্র
# 4  বাংলাদেশ জাতীয়তাবাদী দল - বি.এন.পি
#
#                                            affidavit  \
# 0  মোঃ সাব্বির আহমেদ_হলফনামা | https://onss.ecs.g...
# 1  মুহাম্মদ মুস্তাফিজুর রহমান_হলফনামা | https://o...
# 2  মাহমুদা আলম মিতু_হলফনামা | https://onss.ecs.go...
# 3  এম, মঈন আলম ফিরোজী_হলফনামা | https://onss.ecs....
# 4  রফিকুল ইসলাম জামাল_হলফনামা | https://onss.ecs....
#
#                                        election_fund  \
# 0  মোঃ সাব্বির আহমেদ_নির্বাচনী ব্যয় ও ব্যক্তিগত স...
# 1  মুহাম্মদ মুস্তাফিজুর রহমান_নির্বাচনী ব্যয় ও ব্...
# 2  মাহমুদা আলম মিতু_নির্বাচনী ব্যয় ও ব্যক্তিগত সম...
# 3  এম, মঈন আলম ফিরোজী_নির্বাচনী ব্যয় ও ব্যক্তিগত ...
# 4  রফিকুল ইসলাম জামাল_নির্বাচনী ব্যয় ও ব্যক্তিগত ...
#
#                                           tax_return
# 0  মোঃ সাব্বির আহমেদ_আয়কর রিটার্ন | https://onss....
# 1  মুহাম্মদ মুস্তাফিজুর রহমান_আয়কর রিটার্ন | http...
# 2  মাহমুদা আলম মিতু_আয়কর রিটার্ন | https://onss.e...
# 3  এম, মঈন আলম ফিরোজী_আয়কর রিটার্ন | https://onss...
# 4  রফিকুল ইসলাম জামাল_আয়কর রিটার্ন | https://onss...

# %%
dfp = dfcan.party.value_counts().reset_index()
dfp.columns = ['party', 'counts']
dfp.head()
# Out:
#                                 party  counts
# 0                           স্বতন্ত্র     455
# 1  বাংলাদেশ জাতীয়তাবাদী দল - বি.এন.পি     342
# 2            বাংলাদেশ জামায়াতে ইসলামী     262
# 3             ইসলামী আন্দোলন বাংলাদেশ     249
# 4                        জাতীয় পার্টি     173

# %%
dfp.to_csv('data/party.csv', index=False)

# %%
dfp = pd.read_csv('data/party-en.csv')
dfp.head()
# Out:
#                                 party  counts                   party_en
# 0                           স্বতন্ত্র     455                Independent
# 1  বাংলাদেশ জাতীয়তাবাদী দল - বি.এন.পি     342                        BNP
# 2            বাংলাদেশ জামায়াতে ইসলামী     262                     Jamaat
# 3             ইসলামী আন্দোলন বাংলাদেশ     249  Islami Andolan Bangladesh
# 4                        জাতীয় পার্টি     173                       JaPa

# %%
dfclean = pd.read_csv('data/data-clean-alternative.csv')
dfclean.head()
# Out:
#                          Unnamed: 0                 name_bn  zillaID  \
# 0             1,109,মশিউর রহমান.txt             মশিউর রহমান        1
# 1         1,109,মোঃ অলি উল্লাহ.txt         মোঃ অলি উল্লাহ        1
# 2      1,109,মোঃ জামাল হোসাইন.txt      মোঃ জামাল হোসাইন        1
# 3  1,109,মোঃ জাহাঙ্গীর হোসাইন.txt  মোঃ জাহাঙ্গীর হোসাইন        1
# 4      1,109,মোঃ মুহিব্বুল্যাহ.txt      মোঃ মুহিব্বুল্যাহ        1
#
#    constituencyID           tin              father           mother  \
# 0             109  2.519764e+11                 NaN              NaN
# 1             109           NaN                 NaN              NaN
# 2             109  4.662755e+11  md moslem ali khan      aleya begum
# 3             109  7.965867e+11           abdul maj  ms rabia khatun
# 4             109  2.489017e+11                 NaN              NaN
#
#             nid                                current_addr  \
# 0           NaN                                         NaN
# 1  2.802324e+09                                         NaN
# 2  3.734087e+09  101 nasiruddin shardar lane sutrapur dhaka
# 3  9.550678e+09         23 naya paltan flat bc paltan dhaka
# 4           NaN                                         NaN
#
#                                       permanent_addr     shown     paid  \
# 0                                                NaN       NaN      NaN
# 1                                                NaN  800000.0  45000.0
# 2  khanbari vill jaliaghata po rupdon ps pathorgh...    5000.0   5000.0
# 3      badarkhali goiri chonna barguna sadar barguna  471500.0   7150.0
# 4                                                NaN       NaN      NaN
#
#       wealth                   text_name           cert_name  \
# 0        NaN                         NaN                 NaN
# 1        NaN            md oli ullah                     NaN
# 2   713000.0        md jamal hossain        md jamal hossain
# 3  3890900.0     md jahangir hossain      mdjahangir hossain
# 4        NaN       md muhibbullah as                     NaN
#
#              slip_name
# 0                  NaN
# 1                  NaN
# 2     md jamal hossain
# 3  md jahangir hossain
# 4                  NaN

# %%
dfclean.reset_index()
dfclean.head()
# Out:
#                          Unnamed: 0                 name_bn  zillaID  \
# 0             1,109,মশিউর রহমান.txt             মশিউর রহমান        1
# 1         1,109,মোঃ অলি উল্লাহ.txt         মোঃ অলি উল্লাহ        1
# 2      1,109,মোঃ জামাল হোসাইন.txt      মোঃ জামাল হোসাইন        1
# 3  1,109,মোঃ জাহাঙ্গীর হোসাইন.txt  মোঃ জাহাঙ্গীর হোসাইন        1
# 4      1,109,মোঃ মুহিব্বুল্যাহ.txt      মোঃ মুহিব্বুল্যাহ        1
#
#    constituencyID           tin              father           mother  \
# 0             109  2.519764e+11                 NaN              NaN
# 1             109           NaN                 NaN              NaN
# 2             109  4.662755e+11  md moslem ali khan      aleya begum
# 3             109  7.965867e+11           abdul maj  ms rabia khatun
# 4             109  2.489017e+11                 NaN              NaN
#
#             nid                                current_addr  \
# 0           NaN                                         NaN
# 1  2.802324e+09                                         NaN
# 2  3.734087e+09  101 nasiruddin shardar lane sutrapur dhaka
# 3  9.550678e+09         23 naya paltan flat bc paltan dhaka
# 4           NaN                                         NaN
#
#                                       permanent_addr     shown     paid  \
# 0                                                NaN       NaN      NaN
# 1                                                NaN  800000.0  45000.0
# 2  khanbari vill jaliaghata po rupdon ps pathorgh...    5000.0   5000.0
# 3      badarkhali goiri chonna barguna sadar barguna  471500.0   7150.0
# 4                                                NaN       NaN      NaN
#
#       wealth                   text_name           cert_name  \
# 0        NaN                         NaN                 NaN
# 1        NaN            md oli ullah                     NaN
# 2   713000.0        md jamal hossain        md jamal hossain
# 3  3890900.0     md jahangir hossain      mdjahangir hossain
# 4        NaN       md muhibbullah as                     NaN
#
#              slip_name
# 0                  NaN
# 1                  NaN
# 2     md jamal hossain
# 3  md jahangir hossain
# 4                  NaN

# %%
dfclean = dfclean.rename(columns={'Unnamed: 0': 'filename'})
dfclean.head()
# Out:
#                            filename                 name_bn  zillaID  \
# 0             1,109,মশিউর রহমান.txt             মশিউর রহমান        1
# 1         1,109,মোঃ অলি উল্লাহ.txt         মোঃ অলি উল্লাহ        1
# 2      1,109,মোঃ জামাল হোসাইন.txt      মোঃ জামাল হোসাইন        1
# 3  1,109,মোঃ জাহাঙ্গীর হোসাইন.txt  মোঃ জাহাঙ্গীর হোসাইন        1
# 4      1,109,মোঃ মুহিব্বুল্যাহ.txt      মোঃ মুহিব্বুল্যাহ        1
#
#    constituencyID           tin              father           mother  \
# 0             109  2.519764e+11                 NaN              NaN
# 1             109           NaN                 NaN              NaN
# 2             109  4.662755e+11  md moslem ali khan      aleya begum
# 3             109  7.965867e+11           abdul maj  ms rabia khatun
# 4             109  2.489017e+11                 NaN              NaN
#
#             nid                                current_addr  \
# 0           NaN                                         NaN
# 1  2.802324e+09                                         NaN
# 2  3.734087e+09  101 nasiruddin shardar lane sutrapur dhaka
# 3  9.550678e+09         23 naya paltan flat bc paltan dhaka
# 4           NaN                                         NaN
#
#                                       permanent_addr     shown     paid  \
# 0                                                NaN       NaN      NaN
# 1                                                NaN  800000.0  45000.0
# 2  khanbari vill jaliaghata po rupdon ps pathorgh...    5000.0   5000.0
# 3      badarkhali goiri chonna barguna sadar barguna  471500.0   7150.0
# 4                                                NaN       NaN      NaN
#
#       wealth                   text_name           cert_name  \
# 0        NaN                         NaN                 NaN
# 1        NaN            md oli ullah                     NaN
# 2   713000.0        md jamal hossain        md jamal hossain
# 3  3890900.0     md jahangir hossain      mdjahangir hossain
# 4        NaN       md muhibbullah as                     NaN
#
#              slip_name
# 0                  NaN
# 1                  NaN
# 2     md jamal hossain
# 3  md jahangir hossain
# 4                  NaN

# %%
dfmp = pd.merge(dfcan, dfp, how='left', on='party')
dfmp.head()
# Out:
#    zillaID  constituencyID                        name  \
# 0        4             125           মোঃ সাব্বির আহমেদ
# 1        4             125  মুহাম্মদ মুস্তাফিজুর রহমান
# 2        4             125            মাহমুদা আলম মিতু
# 3        4             125          এম, মঈন আলম ফিরোজী
# 4        4             125          রফিকুল ইসলাম জামাল
#
#                                                  img  \
# 0  https://onss.ecs.gov.bd/document-service/api/v...
# 1  https://onss.ecs.gov.bd/document-service/api/v...
# 2  https://onss.ecs.gov.bd/document-service/api/v...
# 3  https://onss.ecs.gov.bd/document-service/api/v...
# 4  https://onss.ecs.gov.bd/document-service/api/v...
#
#                                 party  \
# 0                           স্বতন্ত্র
# 1               বাংলাদেশ লেবার পার্টি
# 2          জাতীয় নাগরিক পার্টি-এনসিপি
# 3                           স্বতন্ত্র
# 4  বাংলাদেশ জাতীয়তাবাদী দল - বি.এন.পি
#
#                                            affidavit  \
# 0  মোঃ সাব্বির আহমেদ_হলফনামা | https://onss.ecs.g...
# 1  মুহাম্মদ মুস্তাফিজুর রহমান_হলফনামা | https://o...
# 2  মাহমুদা আলম মিতু_হলফনামা | https://onss.ecs.go...
# 3  এম, মঈন আলম ফিরোজী_হলফনামা | https://onss.ecs....
# 4  রফিকুল ইসলাম জামাল_হলফনামা | https://onss.ecs....
#
#                                        election_fund  \
# 0  মোঃ সাব্বির আহমেদ_নির্বাচনী ব্যয় ও ব্যক্তিগত স...
# 1  মুহাম্মদ মুস্তাফিজুর রহমান_নির্বাচনী ব্যয় ও ব্...
# 2  মাহমুদা আলম মিতু_নির্বাচনী ব্যয় ও ব্যক্তিগত সম...
# 3  এম, মঈন আলম ফিরোজী_নির্বাচনী ব্যয় ও ব্যক্তিগত ...
# 4  রফিকুল ইসলাম জামাল_নির্বাচনী ব্যয় ও ব্যক্তিগত ...
#
#                                           tax_return  counts  \
# 0  মোঃ সাব্বির আহমেদ_আয়কর রিটার্ন | https://onss....     455
# 1  মুহাম্মদ মুস্তাফিজুর রহমান_আয়কর রিটার্ন | http...      19
# 2  মাহমুদা আলম মিতু_আয়কর রিটার্ন | https://onss.e...      38
# 3  এম, মঈন আলম ফিরোজী_আয়কর রিটার্ন | https://onss...     455
# 4  রফিকুল ইসলাম জামাল_আয়কর রিটার্ন | https://onss...     342
#
#                  party_en
# 0             Independent
# 1  Bangladesh Labor Party
# 2                     NCP
# 3             Independent
# 4                     BNP

# %%
def get_filename(row):
    return f"{row['zillaID']},{row['constituencyID']},{row['name']}.txt"

dfmp['filename'] = dfmp.apply(get_filename, axis=1)
dfmp.head()
# Out:
#    zillaID  constituencyID                        name  \
# 0        4             125           মোঃ সাব্বির আহমেদ
# 1        4             125  মুহাম্মদ মুস্তাফিজুর রহমান
# 2        4             125            মাহমুদা আলম মিতু
# 3        4             125          এম, মঈন আলম ফিরোজী
# 4        4             125          রফিকুল ইসলাম জামাল
#
#                                                  img  \
# 0  https://onss.ecs.gov.bd/document-service/api/v...
# 1  https://onss.ecs.gov.bd/document-service/api/v...
# 2  https://onss.ecs.gov.bd/document-service/api/v...
# 3  https://onss.ecs.gov.bd/document-service/api/v...
# 4  https://onss.ecs.gov.bd/document-service/api/v...
#
#                                 party  \
# 0                           স্বতন্ত্র
# 1               বাংলাদেশ লেবার পার্টি
# 2          জাতীয় নাগরিক পার্টি-এনসিপি
# 3                           স্বতন্ত্র
# 4  বাংলাদেশ জাতীয়তাবাদী দল - বি.এন.পি
#
#                                            affidavit  \
# 0  মোঃ সাব্বির আহমেদ_হলফনামা | https://onss.ecs.g...
# 1  মুহাম্মদ মুস্তাফিজুর রহমান_হলফনামা | https://o...
# 2  মাহমুদা আলম মিতু_হলফনামা | https://onss.ecs.go...
# 3  এম, মঈন আলম ফিরোজী_হলফনামা | https://onss.ecs....
# 4  রফিকুল ইসলাম জামাল_হলফনামা | https://onss.ecs....
#
#                                        election_fund  \
# 0  মোঃ সাব্বির আহমেদ_নির্বাচনী ব্যয় ও ব্যক্তিগত স...
# 1  মুহাম্মদ মুস্তাফিজুর রহমান_নির্বাচনী ব্যয় ও ব্...
# 2  মাহমুদা আলম মিতু_নির্বাচনী ব্যয় ও ব্যক্তিগত সম...
# 3  এম, মঈন আলম ফিরোজী_নির্বাচনী ব্যয় ও ব্যক্তিগত ...
# 4  রফিকুল ইসলাম জামাল_নির্বাচনী ব্যয় ও ব্যক্তিগত ...
#
#                                           tax_return  counts  \
# 0  মোঃ সাব্বির আহমেদ_আয়কর রিটার্ন | https://onss....     455
# 1  মুহাম্মদ মুস্তাফিজুর রহমান_আয়কর রিটার্ন | http...      19
# 2  মাহমুদা আলম মিতু_আয়কর রিটার্ন | https://onss.e...      38
# 3  এম, মঈন আলম ফিরোজী_আয়কর রিটার্ন | https://onss...     455
# 4  রফিকুল ইসলাম জামাল_আয়কর রিটার্ন | https://onss...     342
#
#                  party_en                              filename
# 0             Independent           4,125,মোঃ সাব্বির আহমেদ.txt
# 1  Bangladesh Labor Party  4,125,মুহাম্মদ মুস্তাফিজুর রহমান.txt
# 2                     NCP            4,125,মাহমুদা আলম মিতু.txt
# 3             Independent          4,125,এম, মঈন আলম ফিরোজী.txt
# 4                     BNP          4,125,রফিকুল ইসলাম জামাল.txt

# %%
dfmc = pd.merge(dfclean, dfmp, how='left', on='filename')
dfmc.head()
# Out:
#                            filename                 name_bn  zillaID_x  \
# 0             1,109,মশিউর রহমান.txt             মশিউর রহমান          1
# 1         1,109,মোঃ অলি উল্লাহ.txt         মোঃ অলি উল্লাহ          1
# 2      1,109,মোঃ জামাল হোসাইন.txt      মোঃ জামাল হোসাইন          1
# 3  1,109,মোঃ জাহাঙ্গীর হোসাইন.txt  মোঃ জাহাঙ্গীর হোসাইন          1
# 4      1,109,মোঃ মুহিব্বুল্যাহ.txt      মোঃ মুহিব্বুল্যাহ          1
#
#    constituencyID_x           tin              father           mother  \
# 0               109  2.519764e+11                 NaN              NaN
# 1               109           NaN                 NaN              NaN
# 2               109  4.662755e+11  md moslem ali khan      aleya begum
# 3               109  7.965867e+11           abdul maj  ms rabia khatun
# 4               109  2.489017e+11                 NaN              NaN
#
#             nid                                current_addr  \
# 0           NaN                                         NaN
# 1  2.802324e+09                                         NaN
# 2  3.734087e+09  101 nasiruddin shardar lane sutrapur dhaka
# 3  9.550678e+09         23 naya paltan flat bc paltan dhaka
# 4           NaN                                         NaN
#
#                                       permanent_addr  ...  zillaID_y  \
# 0                                                NaN  ...          1
# 1                                                NaN  ...          1
# 2  khanbari vill jaliaghata po rupdon ps pathorgh...  ...          1
# 3      badarkhali goiri chonna barguna sadar barguna  ...          1
# 4                                                NaN  ...          1
#
#    constituencyID_y                    name  \
# 0               109             মশিউর রহমান
# 1               109         মোঃ অলি উল্লাহ
# 2               109      মোঃ জামাল হোসাইন
# 3               109  মোঃ জাহাঙ্গীর হোসাইন
# 4               109      মোঃ মুহিব্বুল্যাহ
#
#                                                  img  \
# 0  https://onss.ecs.gov.bd/document-service/api/v...
# 1  https://onss.ecs.gov.bd/document-service/api/v...
# 2  https://onss.ecs.gov.bd/document-service/api/v...
# 3  https://onss.ecs.gov.bd/document-service/api/v...
# 4  https://onss.ecs.gov.bd/document-service/api/v...
#
#                       party  \
# 0                 স্বতন্ত্র
# 1   ইসলামী আন্দোলন বাংলাদেশ
# 2       জাতীয় পার্টি - জেপি
# 3              খেলাফত মজলিস
# 4  বাংলাদেশ জামায়াতে ইসলামী
#
#                                            affidavit  \
# 0  মশিউর রহমান_হলফনামা | https://onss.ecs.gov.bd/...
# 1  মোঃ অলি উল্লাহ_হলফনামা | https://onss.ecs.gov...
# 2  মোঃ জামাল হোসাইন_হলফনামা | https://onss.ecs....
# 3  মোঃ জাহাঙ্গীর হোসাইন_হলফনামা | https://onss....
# 4  মোঃ মুহিব্বুল্যাহ_হলফনামা | https://onss.ecs....
#
#                                        election_fund  \
# 0  মশিউর রহমান_নির্বাচনী ব্যয় ও ব্যক্তিগত সম্পদের...
# 1  মোঃ অলি উল্লাহ_নির্বাচনী ব্যয় ও ব্যক্তিগত সম্...
# 2  মোঃ জামাল হোসাইন_নির্বাচনী ব্যয় ও ব্যক্তিগত ...
# 3  মোঃ জাহাঙ্গীর হোসাইন_নির্বাচনী ব্যয় ও ব্যক্ত...
# 4  মোঃ মুহিব্বুল্যাহ_নির্বাচনী ব্যয় ও ব্যক্তিগত ...
#
#                                           tax_return counts  \
# 0  মশিউর রহমান_আয়কর রিটার্ন | https://onss.ecs.go...    455
# 1  মোঃ অলি উল্লাহ_আয়কর রিটার্ন | https://onss.ec...    249
# 2  মোঃ জামাল হোসাইন_আয়কর রিটার্ন | https://onss...     46
# 3  মোঃ জাহাঙ্গীর হোসাইন_আয়কর রিটার্ন | https://...     67
# 4  মোঃ মুহিব্বুল্যাহ_আয়কর রিটার্ন | https://onss...    262
#
#                     party_en
# 0                Independent
# 1  Islami Andolan Bangladesh
# 2                 JP (Manju)
# 3           Khelafat Majlish
# 4                     Jamaat
#
# [5 rows x 26 columns]

# %%
dfmc.columns
# Out:
# Index(['filename', 'name_bn', 'zillaID_x', 'constituencyID_x', 'tin', 'father',
#        'mother', 'nid', 'current_addr', 'permanent_addr', 'shown', 'paid',
#        'wealth', 'text_name', 'cert_name', 'slip_name', 'zillaID_y',
#        'constituencyID_y', 'name', 'img', 'party', 'affidavit',
#        'election_fund', 'tax_return', 'counts', 'party_en'],
#       dtype='object')

# %%
cols_to_keep = [
    'filename', 'name_bn', 'zillaID_x', 'constituencyID_x', 'tin', 'father',
    'mother', 'nid', 'current_addr', 'permanent_addr', 'shown', 'paid',
    'wealth', 'text_name', 'cert_name', 'slip_name', 'party_en'
]

dfmc = dfmc[cols_to_keep]
dfmc.head()
# Out:
#                            filename                 name_bn  zillaID_x  \
# 0             1,109,মশিউর রহমান.txt             মশিউর রহমান          1
# 1         1,109,মোঃ অলি উল্লাহ.txt         মোঃ অলি উল্লাহ          1
# 2      1,109,মোঃ জামাল হোসাইন.txt      মোঃ জামাল হোসাইন          1
# 3  1,109,মোঃ জাহাঙ্গীর হোসাইন.txt  মোঃ জাহাঙ্গীর হোসাইন          1
# 4      1,109,মোঃ মুহিব্বুল্যাহ.txt      মোঃ মুহিব্বুল্যাহ          1
#
#    constituencyID_x           tin              father           mother  \
# 0               109  2.519764e+11                 NaN              NaN
# 1               109           NaN                 NaN              NaN
# 2               109  4.662755e+11  md moslem ali khan      aleya begum
# 3               109  7.965867e+11           abdul maj  ms rabia khatun
# 4               109  2.489017e+11                 NaN              NaN
#
#             nid                                current_addr  \
# 0           NaN                                         NaN
# 1  2.802324e+09                                         NaN
# 2  3.734087e+09  101 nasiruddin shardar lane sutrapur dhaka
# 3  9.550678e+09         23 naya paltan flat bc paltan dhaka
# 4           NaN                                         NaN
#
#                                       permanent_addr     shown     paid  \
# 0                                                NaN       NaN      NaN
# 1                                                NaN  800000.0  45000.0
# 2  khanbari vill jaliaghata po rupdon ps pathorgh...    5000.0   5000.0
# 3      badarkhali goiri chonna barguna sadar barguna  471500.0   7150.0
# 4                                                NaN       NaN      NaN
#
#       wealth                   text_name           cert_name  \
# 0        NaN                         NaN                 NaN
# 1        NaN            md oli ullah                     NaN
# 2   713000.0        md jamal hossain        md jamal hossain
# 3  3890900.0     md jahangir hossain      mdjahangir hossain
# 4        NaN       md muhibbullah as                     NaN
#
#              slip_name                   party_en
# 0                  NaN                Independent
# 1                  NaN  Islami Andolan Bangladesh
# 2     md jamal hossain                 JP (Manju)
# 3  md jahangir hossain           Khelafat Majlish
# 4                  NaN                     Jamaat

# %%
dfmc = dfmc.rename(columns={'zillaID_x': 'zillaID', 'constituencyID_x': 'constituencyID'})
dfmc.head()
# Out:
#                            filename                 name_bn  zillaID  \
# 0             1,109,মশিউর রহমান.txt             মশিউর রহমান        1
# 1         1,109,মোঃ অলি উল্লাহ.txt         মোঃ অলি উল্লাহ        1
# 2      1,109,মোঃ জামাল হোসাইন.txt      মোঃ জামাল হোসাইন        1
# 3  1,109,মোঃ জাহাঙ্গীর হোসাইন.txt  মোঃ জাহাঙ্গীর হোসাইন        1
# 4      1,109,মোঃ মুহিব্বুল্যাহ.txt      মোঃ মুহিব্বুল্যাহ        1
#
#    constituencyID           tin              father           mother  \
# 0             109  2.519764e+11                 NaN              NaN
# 1             109           NaN                 NaN              NaN
# 2             109  4.662755e+11  md moslem ali khan      aleya begum
# 3             109  7.965867e+11           abdul maj  ms rabia khatun
# 4             109  2.489017e+11                 NaN              NaN
#
#             nid                                current_addr  \
# 0           NaN                                         NaN
# 1  2.802324e+09                                         NaN
# 2  3.734087e+09  101 nasiruddin shardar lane sutrapur dhaka
# 3  9.550678e+09         23 naya paltan flat bc paltan dhaka
# 4           NaN                                         NaN
#
#                                       permanent_addr     shown     paid  \
# 0                                                NaN       NaN      NaN
# 1                                                NaN  800000.0  45000.0
# 2  khanbari vill jaliaghata po rupdon ps pathorgh...    5000.0   5000.0
# 3      badarkhali goiri chonna barguna sadar barguna  471500.0   7150.0
# 4                                                NaN       NaN      NaN
#
#       wealth                   text_name           cert_name  \
# 0        NaN                         NaN                 NaN
# 1        NaN            md oli ullah                     NaN
# 2   713000.0        md jamal hossain        md jamal hossain
# 3  3890900.0     md jahangir hossain      mdjahangir hossain
# 4        NaN       md muhibbullah as                     NaN
#
#              slip_name                   party_en
# 0                  NaN                Independent
# 1                  NaN  Islami Andolan Bangladesh
# 2     md jamal hossain                 JP (Manju)
# 3  md jahangir hossain           Khelafat Majlish
# 4                  NaN                     Jamaat

# %%
dfmc.to_csv('data/data-clean-alternative-final.csv', index=False)
